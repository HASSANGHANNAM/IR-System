# %%
# !pip install ir_datasets
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 866.1/866.1 kB 14.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.7/149.7 kB 10.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.6/45.6 kB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 45.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 53.4 MB/s eta 0:00:00
# ...
#   Created wheel for warc3-wet-clueweb09: filename=warc3_wet_clueweb09-0.2.5-py3-none-any.whl size=18919 sha256=b2a08165d71508437e047a5f4efa002625489ef87ffea64d26c5a3b524c48cf4
#   Stored in directory: /root/.cache/pip/wheels/f6/85/c2/9f0f621def52a1d5db7d29984f81e45f9fb6dfeb1a4eb6e31c
# ...
#   Created wheel for cbor: filename=cbor-1.0.0-cp312-cp312-linux_x86_64.whl size=55020 sha256=d8ab7454eaa9b737f8f58cadceea2c2dd97509d4776fe5fab83f5a3fad891ba4
# ...

# %%
import ir_datasets

# %%
dataset = ir_datasets.load("cord19/fulltext/trec-covid")

# %%
import ir_datasets
dataset = ir_datasets.load("beir/webis-touche2020")

print(f"عدد الوثائق: {dataset.docs_count():,}")     # 382,545
print(f"عدد الاستعلامات: {dataset.queries_count():,}")   # 49
print(f"عدد أحكام الصلة (qrels): {dataset.qrels_count():,}") # 2,962
# Out:
# عدد الوثائق: 382,545
# عدد الاستعلامات: 49
# عدد أحكام الصلة (qrels): 2,962

# %%
import ir_datasets
dataset = ir_datasets.load("beir/webis-touche2020")
for query in dataset.queries_iter():
    query # namedtuple<query_id, text, description, narrative>
# Out:
# [INFO] [starting] opening zip file
# [INFO] If you have a local copy of https://macavaney.us/beir-webis-touche2020-v1.zip, you can symlink it here to avoid downloading it again: /root/.ir_datasets/downloads/5ec7f8b18481fc2e9b3964ad1b22dd28
# [INFO] [starting] https://macavaney.us/beir-webis-touche2020-v1.zip
# [INFO] [finished] https://macavaney.us/beir-webis-touche2020-v1.zip: [00:02] [227MB] [106MB/s]
# [INFO] [finished] opening zip file [2.41s]
